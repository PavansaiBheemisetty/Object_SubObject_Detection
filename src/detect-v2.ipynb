# %%
from ultralytics import YOLO
import cv2
import os
import json
import time
from datetime import datetime
import numpy as np

class HierarchicalDetector:
    def __init__(self, main_model_path='yolov8n.pt', sub_model_path='best.pt'):
        self.main_model = YOLO(main_model_path)
        self.sub_model = YOLO(sub_model_path)
        self.main_model_classes = self.main_model.model.names
        self.sub_model_classes = self.sub_model.model.names
        self.object_count = {}
        self.save_dir = '../data/detected_objects'
        os.makedirs(self.save_dir, exist_ok=True)
        

        self.frame_size = (480, 360)
        self.main_conf_threshold = 0.3
        self.sub_conf_threshold = 0.3
        
  
        self.prev_detections = []
        
       
        self.saved_objects = set()
    
    def format_detections(self, detections):
        formatted_detections = []
        
        for det in detections:
            main_detection = {
                "object": det['object'],
                "id": det['id'],
                "bbox": det['bbox']
            }
            
            if det['subobjects']:
                sub = det['subobjects'][0]
                main_detection["subobject"] = {
                    "object": sub['object'],
                    "id": sub['id'],
                    "bbox": sub['bbox']
                }
            
            formatted_detections.append(main_detection)
        
        return formatted_detections

    def get_unique_id(self, class_name):
        if class_name not in self.object_count:
            self.object_count[class_name] = 0
        self.object_count[class_name] += 1
        return self.object_count[class_name]
    
    def draw_detections(self, frame, detections):
        """Draw detections on frame"""
        display_frame = frame.copy()
        
        for det in detections:
            main_bbox = det['bbox']
            main_obj_name = det['object']
            main_obj_id = det['id']
            main_conf = det['confidence']
            
            cv2.rectangle(display_frame, 
                         (main_bbox[0], main_bbox[1]),
                         (main_bbox[2], main_bbox[3]), 
                         (0, 255, 0), 2)
            label = f"{main_obj_name} {main_obj_id} ({main_conf:.2f})"
            cv2.putText(display_frame, label, 
                       (main_bbox[0], main_bbox[1] - 10),
                       cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)
            
            for sub_obj in det['subobjects']:
                sub_bbox = sub_obj['bbox']
                sub_obj_name = sub_obj['object']
                sub_obj_id = sub_obj['id']
                sub_conf = sub_obj['confidence']
                
                cv2.rectangle(display_frame,
                            (sub_bbox[0], sub_bbox[1]),
                            (sub_bbox[2], sub_bbox[3]),
                            (255, 0, 0), 2)
                sub_label = f"{sub_obj_name} {sub_obj_id} ({sub_conf:.2f})"
                cv2.putText(display_frame, sub_label,
                           (sub_bbox[0], sub_bbox[1] - 10),
                           cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 0, 0), 2)
        
        return display_frame

    def process_frame(self, frame):
        detections = []
        
        frame = cv2.resize(frame, self.frame_size)
        
        
        results_main = self.main_model(frame, conf=self.main_conf_threshold)
        
        for result_main in results_main:
            boxes = result_main.boxes
            if boxes is None or len(boxes) == 0:
                continue
            
            for box, main_cls, conf in zip(boxes.xyxy, boxes.cls, boxes.conf):
                main_bbox = list(map(int, box))
                main_cls_idx = int(main_cls.item())
                main_conf = float(conf.item())
                main_obj_name = self.main_model_classes[main_cls_idx]
                main_obj_id = self.get_unique_id(main_obj_name)
                

            
                main_obj_identifier = f"{main_obj_name}{main_obj_id}"
                
             
                if (main_bbox[2] - main_bbox[0]) > 20 and (main_bbox[3] - main_bbox[1]) > 20:
                    cropped = frame[main_bbox[1]:main_bbox[3], main_bbox[0]:main_bbox[2]]
                    sub_objects = []
                    
                   
                    results_sub = self.sub_model(cropped, conf=self.sub_conf_threshold)
                    
                    for result_sub in results_sub:
                        sub_boxes = result_sub.boxes
                        if sub_boxes is None or len(sub_boxes) == 0:
                            continue
                        
                        for sub_box, sub_cls, sub_conf in zip(sub_boxes.xyxy, sub_boxes.cls, sub_boxes.conf):
                            sub_cls_idx = int(sub_cls.item())
                            sub_conf = float(sub_conf.item())
                            sub_obj_name = self.sub_model_classes[sub_cls_idx]
                            sub_obj_id = self.get_unique_id(sub_obj_name)
                            
                           
                            sub_obj_identifier = f"{main_obj_identifier}_{sub_obj_name}"
                            
                            
                            sub_bbox = list(map(int, sub_box))
                            global_bbox = [
                                main_bbox[0] + sub_bbox[0],
                                main_bbox[1] + sub_bbox[1],
                                main_bbox[0] + sub_bbox[2],
                                main_bbox[1] + sub_bbox[3]
                            ]
                            
                           
                            if sub_conf > 0.5 and sub_obj_identifier not in self.saved_objects:
                                save_path = os.path.join(
                                    self.save_dir,
                                    f"{main_obj_name}{main_obj_id}_{sub_obj_name}{sub_obj_id}.jpg"
                                )
                                cv2.imwrite(save_path, cropped)
                                self.saved_objects.add(sub_obj_identifier)
                                
                                sub_objects.append({
                                    "object": sub_obj_name,
                                    "id": sub_obj_id,
                                    "confidence": sub_conf,
                                    "bbox": global_bbox,
                                    "image_path": save_path
                                })
                            elif sub_conf > 0.5: 
                                sub_objects.append({
                                    "object": sub_obj_name,
                                    "id": sub_obj_id,
                                    "confidence": sub_conf,
                                    "bbox": global_bbox
                                })
                    
                    detection = {
                        "object": main_obj_name,
                        "id": main_obj_id,
                        "confidence": main_conf,
                        "bbox": main_bbox,
                        "subobjects": sub_objects
                    }
                    detections.append(detection)
        
     
        if len(detections) > 0:
            self.prev_detections = detections
        
        
        if len(detections) == 0 and len(self.prev_detections) > 0:
            detections = self.prev_detections
        
        
        display_frame = self.draw_detections(frame, detections)
        
        return display_frame, detections

    def process_video(self, video_path, output_path=None):
        """Process video with smooth output"""
        cap = cv2.VideoCapture(video_path)
        frame_count = 0
        total_time = 0
        all_detections = []
        
        if output_path:
            fourcc = cv2.VideoWriter_fourcc(*'mp4v')
            out = cv2.VideoWriter(output_path, fourcc, 30.0, self.frame_size)
        
        while cap.isOpened():
            ret, frame = cap.read()
            if not ret:
                break
            
            start_time = time.time()
            
           
            display_frame, detections = self.process_frame(frame)
            
            
            formatted_detections = self.format_detections(detections)
            
            process_time = time.time() - start_time
            total_time += process_time
            current_fps = 1 / (process_time + 1e-6)
            
         
            cv2.putText(display_frame, f"FPS: {current_fps:.1f}",
                       (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
            
            if output_path:
                out.write(display_frame)
            
            cv2.imshow('Detection', display_frame)
            
            if len(formatted_detections) > 0:
                all_detections.append(formatted_detections)
            
            if cv2.waitKey(1) & 0xFF == ord('q'):
                break
            
            frame_count += 1
        
        metrics = {
            "total_frames": frame_count,
            "total_time": total_time,
            "average_fps": frame_count / (total_time + 1e-6)
        }
        
        cap.release()
        if output_path:
            out.release()
        cv2.destroyAllWindows()
        
        return metrics, all_detections


if __name__ == "__main__":
    detector = HierarchicalDetector('yolov8n.pt', 'best.pt')
    video_path = '../data/test.mp4'
    output_path = '../results/output.mp4'
    
    print("Processing video...")
    metrics, detections = detector.process_video(video_path, output_path)
    
    with open('../results/detections.json', 'w') as f:
        json.dump(detections, f, indent=4)
    
    print("\nPerformance Metrics:")
    print(f"Total Frames: {metrics['total_frames']}")
    print(f"Total Time: {metrics['total_time']:.2f} seconds")
    print(f"Average FPS: {metrics['average_fps']:.2f}")
# Out:
# Processing video...
#
# 0: 480x640 8 persons, 1 car, 4 motorcycles, 1 bus, 4 trucks, 92.2ms
# Speed: 5.5ms preprocess, 92.2ms inference, 6.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 640x256 (no detections), 45.2ms
# Speed: 1.5ms preprocess, 45.2ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 256)
#
# 0: 640x544 1 tyre, 100.0ms
# Speed: 3.5ms preprocess, 100.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 544)
#
# 0: 640x640 1 door, 1 tyre, 130.7ms
# Speed: 3.6ms preprocess, 130.7ms inference, 11.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x256 (no detections), 59.5ms
# Speed: 20.0ms preprocess, 59.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 256)
#
# 0: 640x544 (no detections), 96.3ms
# Speed: 3.0ms preprocess, 96.3ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 544)
#
# 0: 640x640 1 helmet, 108.7ms
# Speed: 4.3ms preprocess, 108.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x288 (no detections), 58.6ms
# Speed: 1.9ms preprocess, 58.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 288)
#
# 0: 640x608 1 door, 94.2ms
# Speed: 2.9ms preprocess, 94.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 416x640 (no detections), 67.0ms
# Speed: 2.3ms preprocess, 67.0ms inference, 0.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 640x480 (no detections), 81.6ms
# Speed: 2.7ms preprocess, 81.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 608x640 (no detections), 98.1ms
# Speed: 3.7ms preprocess, 98.1ms inference, 0.4ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 608x640 (no detections), 92.4ms
# Speed: 3.6ms preprocess, 92.4ms inference, 0.4ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 640x544 1 door, 99.7ms
# Speed: 2.9ms preprocess, 99.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 544)
#
# 0: 640x256 (no detections), 64.2ms
# Speed: 1.9ms preprocess, 64.2ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 256)
#
# 0: 480x640 6 persons, 2 cars, 6 motorcycles, 1 bus, 3 trucks, 135.8ms
# Speed: 3.3ms preprocess, 135.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 640x256 (no detections), 56.4ms
# Speed: 2.0ms preprocess, 56.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 256)
#
# 0: 640x640 (no detections), 108.3ms
# Speed: 3.2ms preprocess, 108.3ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x608 1 helmet, 113.3ms
# Speed: 3.9ms preprocess, 113.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 512x640 1 tyre, 84.0ms
# Speed: 3.0ms preprocess, 84.0ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 640x480 (no detections), 78.1ms
# Speed: 2.0ms preprocess, 78.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x288 (no detections), 57.5ms
# Speed: 1.9ms preprocess, 57.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 288)
#
# 0: 640x640 1 door, 113.7ms
# Speed: 4.1ms preprocess, 113.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x288 (no detections), 52.4ms
# Speed: 1.7ms preprocess, 52.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 288)
#
# 0: 416x640 (no detections), 71.2ms
# Speed: 3.0ms preprocess, 71.2ms inference, 0.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 640x192 (no detections), 44.5ms
# Speed: 1.7ms preprocess, 44.5ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 192)
#
# 0: 608x640 (no detections), 107.2ms
# Speed: 5.2ms preprocess, 107.2ms inference, 0.4ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 640x640 1 door, 109.3ms
# Speed: 2.8ms preprocess, 109.3ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x608 1 door, 105.5ms
# Speed: 3.6ms preprocess, 105.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 384x640 (no detections), 64.0ms
# Speed: 2.0ms preprocess, 64.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x576 1 door, 138.2ms
# Speed: 2.7ms preprocess, 138.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 480x640 5 persons, 2 cars, 6 motorcycles, 1 bus, 4 trucks, 83.0ms
# Speed: 3.6ms preprocess, 83.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 640x640 (no detections), 129.8ms
# Speed: 4.2ms preprocess, 129.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 608x640 1 door, 1 helmet, 109.7ms
# Speed: 4.4ms preprocess, 109.7ms inference, 0.7ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 640x256 (no detections), 51.6ms
# Speed: 1.8ms preprocess, 51.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 256)
#
# 0: 640x512 (no detections), 83.1ms
# Speed: 2.9ms preprocess, 83.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 576x640 1 tyre, 89.3ms
# Speed: 2.8ms preprocess, 89.3ms inference, 0.7ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 640x640 1 door, 95.7ms
# Speed: 2.9ms preprocess, 95.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x224 (no detections), 45.3ms
# Speed: 1.7ms preprocess, 45.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 224)
#
# 0: 640x256 (no detections), 44.7ms
# Speed: 2.1ms preprocess, 44.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 256)
#
# 0: 640x288 (no detections), 50.9ms
# Speed: 2.1ms preprocess, 50.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 288)
#
# 0: 416x640 (no detections), 61.7ms
# Speed: 2.9ms preprocess, 61.7ms inference, 0.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 640x640 1 door, 91.0ms
# Speed: 3.3ms preprocess, 91.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 140.7ms
# Speed: 18.1ms preprocess, 140.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 416x640 (no detections), 91.0ms
# Speed: 3.3ms preprocess, 91.0ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 640x640 (no detections), 121.1ms
# Speed: 4.1ms preprocess, 121.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 door, 71.2ms
# Speed: 2.9ms preprocess, 71.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x576 (no detections), 94.5ms
# Speed: 2.8ms preprocess, 94.5ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 480x640 6 persons, 2 cars, 5 motorcycles, 2 buss, 3 trucks, 71.7ms
# Speed: 3.2ms preprocess, 71.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 576x640 1 tyre, 93.2ms
# Speed: 3.3ms preprocess, 93.2ms inference, 0.6ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 640x640 1 door, 1 tyre, 97.4ms
# Speed: 3.5ms preprocess, 97.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 door, 92.2ms
# Speed: 3.1ms preprocess, 92.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x288 (no detections), 50.6ms
# Speed: 1.6ms preprocess, 50.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 288)
#
# 0: 640x608 (no detections), 91.1ms
# Speed: 2.9ms preprocess, 91.1ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x544 (no detections), 90.3ms
# Speed: 2.9ms preprocess, 90.3ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 544)
#
# 0: 640x320 (no detections), 51.8ms
# Speed: 2.0ms preprocess, 51.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 320)
#
# 0: 608x640 (no detections), 90.5ms
# Speed: 3.5ms preprocess, 90.5ms inference, 0.3ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 416x640 (no detections), 62.8ms
# Speed: 2.4ms preprocess, 62.8ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 640x640 1 door, 92.2ms
# Speed: 3.3ms preprocess, 92.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x288 (no detections), 49.8ms
# Speed: 2.4ms preprocess, 49.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 288)
#
# 0: 640x256 (no detections), 47.6ms
# Speed: 1.9ms preprocess, 47.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 256)
#
# 0: 416x640 (no detections), 62.9ms
# Speed: 2.4ms preprocess, 62.9ms inference, 0.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 640x320 (no detections), 55.0ms
# Speed: 2.0ms preprocess, 55.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 320)
#
# 0: 640x608 2 doors, 87.9ms
# Speed: 3.5ms preprocess, 87.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x256 (no detections), 81.0ms
# Speed: 1.9ms preprocess, 81.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 256)
#
# 0: 640x608 2 doors, 98.3ms
# Speed: 3.3ms preprocess, 98.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 480x640 5 persons, 1 car, 6 motorcycles, 2 buss, 3 trucks, 81.9ms
# Speed: 3.5ms preprocess, 81.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 640x640 (no detections), 99.0ms
# Speed: 3.2ms preprocess, 99.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 544x640 1 tyre, 94.2ms
# Speed: 3.0ms preprocess, 94.2ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 640x288 (no detections), 66.0ms
# Speed: 2.2ms preprocess, 66.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 288)
#
# 0: 640x608 (no detections), 103.4ms
# Speed: 3.4ms preprocess, 103.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x640 1 door, 100.0ms
# Speed: 3.9ms preprocess, 100.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x192 (no detections), 38.2ms
# Speed: 1.4ms preprocess, 38.2ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 192)
#
# 0: 640x512 (no detections), 92.0ms
# Speed: 2.5ms preprocess, 92.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x608 1 door, 93.6ms
# Speed: 4.3ms preprocess, 93.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 608x640 (no detections), 93.7ms
# Speed: 3.5ms preprocess, 93.7ms inference, 0.4ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 640x384 (no detections), 66.4ms
# Speed: 2.7ms preprocess, 66.4ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x256 (no detections), 54.1ms
# Speed: 2.3ms preprocess, 54.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 256)
#
# 0: 640x288 (no detections), 56.8ms
# Speed: 2.1ms preprocess, 56.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 288)
#
# 0: 416x640 (no detections), 69.1ms
# Speed: 2.4ms preprocess, 69.1ms inference, 0.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 640x288 (no detections), 55.8ms
# Speed: 2.5ms preprocess, 55.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 288)
#
# 0: 640x640 1 door, 105.7ms
# Speed: 3.3ms preprocess, 105.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 102.6ms
# Speed: 3.4ms preprocess, 102.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x160 (no detections), 35.1ms
# Speed: 1.6ms preprocess, 35.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 160)
#
# 0: 480x640 5 persons, 2 cars, 6 motorcycles, 1 bus, 2 trucks, 82.7ms
# Speed: 3.2ms preprocess, 82.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 640x640 1 tyre, 98.0ms
# Speed: 3.4ms preprocess, 98.0ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 544x640 1 tyre, 86.9ms
# Speed: 3.2ms preprocess, 86.9ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 640x512 (no detections), 83.7ms
# Speed: 2.5ms preprocess, 83.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x608 1 door, 99.3ms
# Speed: 4.9ms preprocess, 99.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x576 1 door, 83.7ms
# Speed: 2.8ms preprocess, 83.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x256 (no detections), 46.1ms
# Speed: 1.8ms preprocess, 46.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 256)
#
# 0: 640x320 (no detections), 54.2ms
# Speed: 2.5ms preprocess, 54.2ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 320)
#
# 0: 640x256 (no detections), 83.1ms
# Speed: 2.2ms preprocess, 83.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 256)
#
# 0: 640x224 (no detections), 41.9ms
# Speed: 1.8ms preprocess, 41.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 224)
#
# 0: 416x640 (no detections), 65.8ms
# Speed: 2.4ms preprocess, 65.8ms inference, 0.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 640x640 (no detections), 92.5ms
# Speed: 3.2ms preprocess, 92.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 416x640 (no detections), 63.9ms
# Speed: 2.5ms preprocess, 63.9ms inference, 0.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 640x416 (no detections), 64.3ms
# Speed: 2.4ms preprocess, 64.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 608x640 (no detections), 87.0ms
# Speed: 2.9ms preprocess, 87.0ms inference, 0.4ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 640x320 (no detections), 49.3ms
# Speed: 2.4ms preprocess, 49.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 320)
#
# 0: 480x640 5 persons, 1 car, 6 motorcycles, 2 buss, 2 trucks, 69.8ms
# Speed: 3.3ms preprocess, 69.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 640x640 (no detections), 99.0ms
# Speed: 3.0ms preprocess, 99.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 544x640 1 tyre, 85.8ms
# Speed: 2.9ms preprocess, 85.8ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 640x608 1 door, 95.4ms
# Speed: 2.8ms preprocess, 95.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x320 (no detections), 56.4ms
# Speed: 1.8ms preprocess, 56.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 320)
#
# 0: 640x544 1 door, 85.8ms
# Speed: 2.6ms preprocess, 85.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 544)
#
# 0: 640x256 (no detections), 48.7ms
# Speed: 2.3ms preprocess, 48.7ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 256)
#
# 0: 640x288 (no detections), 51.6ms
# Speed: 2.0ms preprocess, 51.6ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 288)
#
# 0: 640x320 (no detections), 57.3ms
# Speed: 2.3ms preprocess, 57.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 320)
#
# 0: 416x640 (no detections), 67.6ms
# Speed: 2.1ms preprocess, 67.6ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 640x544 (no detections), 97.6ms
# Speed: 3.9ms preprocess, 97.6ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 544)
#
# 0: 640x288 (no detections), 56.6ms
# Speed: 2.7ms preprocess, 56.6ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 288)
#
# 0: 640x256 (no detections), 53.4ms
# Speed: 2.0ms preprocess, 53.4ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 256)
#
# 0: 608x640 (no detections), 102.8ms
# Speed: 4.1ms preprocess, 102.8ms inference, 0.4ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 640x448 (no detections), 73.7ms
# Speed: 2.5ms preprocess, 73.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 384x640 (no detections), 103.5ms
# Speed: 2.2ms preprocess, 103.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 480x640 5 persons, 1 car, 6 motorcycles, 2 trucks, 74.4ms
# Speed: 2.9ms preprocess, 74.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 640x640 1 tyre, 96.0ms
# Speed: 3.6ms preprocess, 96.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 544x640 1 tyre, 81.9ms
# Speed: 3.9ms preprocess, 81.9ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 640x576 1 door, 97.0ms
# Speed: 2.6ms preprocess, 97.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x256 (no detections), 58.9ms
# Speed: 1.6ms preprocess, 58.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 256)
#
# 0: 640x256 (no detections), 56.5ms
# Speed: 1.9ms preprocess, 56.5ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 256)
#
# 0: 640x352 (no detections), 73.0ms
# Speed: 2.5ms preprocess, 73.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 70.1ms
# Speed: 2.7ms preprocess, 70.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x480 (no detections), 87.6ms
# Speed: 3.1ms preprocess, 87.6ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 416x640 1 tyre, 79.7ms
# Speed: 3.4ms preprocess, 79.7ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 608x640 (no detections), 96.9ms
# Speed: 3.3ms preprocess, 96.9ms inference, 0.3ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 640x416 (no detections), 69.0ms
# Speed: 2.9ms preprocess, 69.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x416 (no detections), 70.7ms
# Speed: 2.7ms preprocess, 70.7ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x640 (no detections), 98.9ms
# Speed: 3.9ms preprocess, 98.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 5 persons, 1 car, 5 motorcycles, 2 buss, 1 truck, 73.1ms
# Speed: 2.8ms preprocess, 73.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 640x640 (no detections), 91.8ms
# Speed: 3.1ms preprocess, 91.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x608 1 door, 92.9ms
# Speed: 3.4ms preprocess, 92.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x384 (no detections), 60.5ms
# Speed: 2.6ms preprocess, 60.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 608x640 1 tyre, 128.7ms
# Speed: 3.1ms preprocess, 128.7ms inference, 0.6ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 640x320 (no detections), 56.6ms
# Speed: 2.3ms preprocess, 56.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 320)
#
# 0: 640x288 (no detections), 53.2ms
# Speed: 1.9ms preprocess, 53.2ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 288)
#
# 0: 640x256 (no detections), 44.5ms
# Speed: 1.8ms preprocess, 44.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 256)
#
# 0: 640x512 1 tyre, 90.3ms
# Speed: 2.7ms preprocess, 90.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 576x640 (no detections), 93.3ms
# Speed: 3.3ms preprocess, 93.3ms inference, 0.3ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 416x640 1 door, 1 tyre, 65.7ms
# Speed: 3.5ms preprocess, 65.7ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 640x576 1 door, 85.8ms
# Speed: 3.8ms preprocess, 85.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x416 (no detections), 65.8ms
# Speed: 2.1ms preprocess, 65.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x640 (no detections), 93.5ms
# Speed: 3.5ms preprocess, 93.5ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 6 persons, 2 cars, 6 motorcycles, 1 bus, 2 trucks, 74.9ms
# Speed: 3.7ms preprocess, 74.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 640x640 (no detections), 94.3ms
# Speed: 2.9ms preprocess, 94.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x448 (no detections), 67.8ms
# Speed: 2.3ms preprocess, 67.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x224 1 helmet, 45.5ms
# Speed: 2.0ms preprocess, 45.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 224)
#
# 0: 640x288 (no detections), 50.4ms
# Speed: 2.2ms preprocess, 50.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 288)
#
# 0: 640x576 1 door, 85.6ms
# Speed: 2.8ms preprocess, 85.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 608x640 1 tyre, 96.7ms
# Speed: 2.9ms preprocess, 96.7ms inference, 0.8ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 640x352 (no detections), 98.8ms
# Speed: 2.8ms preprocess, 98.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x640 1 door, 98.6ms
# Speed: 3.7ms preprocess, 98.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x288 (no detections), 53.8ms
# Speed: 1.8ms preprocess, 53.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 288)
#
# 0: 640x480 (no detections), 74.1ms
# Speed: 2.6ms preprocess, 74.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 576x640 1 helmet, 87.8ms
# Speed: 3.1ms preprocess, 87.8ms inference, 0.7ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 640x288 (no detections), 52.7ms
# Speed: 1.9ms preprocess, 52.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 288)
#
# 0: 416x640 1 door, 64.4ms
# Speed: 2.7ms preprocess, 64.4ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 640x544 1 door, 78.2ms
# Speed: 2.6ms preprocess, 78.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 544)
#
# 0: 416x640 1 door, 1 tyre, 65.6ms
# Speed: 2.3ms preprocess, 65.6ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 480x640 6 persons, 2 cars, 5 motorcycles, 3 buss, 2 trucks, 73.5ms
# Speed: 3.1ms preprocess, 73.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 640x608 (no detections), 111.0ms
# Speed: 3.1ms preprocess, 111.0ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x576 1 door, 106.5ms
# Speed: 4.8ms preprocess, 106.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x288 (no detections), 57.7ms
# Speed: 1.8ms preprocess, 57.7ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 288)
#
# 0: 512x640 1 tyre, 93.3ms
# Speed: 3.4ms preprocess, 93.3ms inference, 0.6ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 640x352 (no detections), 68.8ms
# Speed: 2.0ms preprocess, 68.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x256 (no detections), 98.4ms
# Speed: 1.9ms preprocess, 98.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 256)
#
# 0: 640x544 1 door, 93.6ms
# Speed: 3.0ms preprocess, 93.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 544)
#
# 0: 640x256 (no detections), 56.7ms
# Speed: 2.1ms preprocess, 56.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 256)
#
# 0: 512x640 (no detections), 99.2ms
# Speed: 2.9ms preprocess, 99.2ms inference, 0.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 640x480 1 door, 84.4ms
# Speed: 2.6ms preprocess, 84.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 89.4ms
# Speed: 3.9ms preprocess, 89.4ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x608 2 doors, 107.1ms
# Speed: 3.5ms preprocess, 107.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 416x640 1 door, 1 tyre, 74.0ms
# Speed: 2.5ms preprocess, 74.0ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 544x640 1 helmet, 84.6ms
# Speed: 3.1ms preprocess, 84.6ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 416x640 1 door, 1 tyre, 67.5ms
# Speed: 2.7ms preprocess, 67.5ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 640x416 (no detections), 70.0ms
# Speed: 2.5ms preprocess, 70.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 608x640 1 door, 90.5ms
# Speed: 3.1ms preprocess, 90.5ms inference, 0.6ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 480x640 8 persons, 5 motorcycles, 2 buss, 3 trucks, 67.4ms
# Speed: 3.5ms preprocess, 67.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 640x640 (no detections), 90.7ms
# Speed: 4.8ms preprocess, 90.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x352 2 helmets, 96.1ms
# Speed: 2.9ms preprocess, 96.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x576 (no detections), 89.0ms
# Speed: 3.1ms preprocess, 89.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 512x640 1 tyre, 91.9ms
# Speed: 3.6ms preprocess, 91.9ms inference, 0.6ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 640x544 (no detections), 86.7ms
# Speed: 2.8ms preprocess, 86.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 544)
#
# 0: 640x320 (no detections), 55.8ms
# Speed: 1.9ms preprocess, 55.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 320)
#
# 0: 640x256 (no detections), 46.9ms
# Speed: 2.3ms preprocess, 46.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 256)
#
# 0: 640x288 (no detections), 52.8ms
# Speed: 2.3ms preprocess, 52.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 288)
#
# 0: 640x640 1 door, 107.3ms
# Speed: 2.8ms preprocess, 107.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 110.4ms
# Speed: 3.5ms preprocess, 110.4ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 door, 124.8ms
# Speed: 4.0ms preprocess, 124.8ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x576 1 door, 105.7ms
# Speed: 3.5ms preprocess, 105.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x480 (no detections), 80.3ms
# Speed: 3.3ms preprocess, 80.3ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 480x640 1 helmet, 76.6ms
# Speed: 3.0ms preprocess, 76.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 448x640 1 door, 1 helmet, 1 tyre, 70.0ms
# Speed: 2.8ms preprocess, 70.0ms inference, 0.8ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 480x640 6 persons, 1 car, 5 motorcycles, 1 bus, 1 truck, 82.9ms
# Speed: 19.7ms preprocess, 82.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 640x320 2 helmets, 58.4ms
# Speed: 2.0ms preprocess, 58.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 320)
#
# 0: 640x640 1 door, 104.6ms
# Speed: 3.4ms preprocess, 104.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x608 1 door, 97.2ms
# Speed: 3.2ms preprocess, 97.2ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 608x640 1 tyre, 105.6ms
# Speed: 3.9ms preprocess, 105.6ms inference, 0.7ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 640x288 (no detections), 55.3ms
# Speed: 1.8ms preprocess, 55.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 288)
#
# 0: 640x320 (no detections), 60.1ms
# Speed: 2.1ms preprocess, 60.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 320)
#
# 0: 640x512 (no detections), 105.9ms
# Speed: 3.9ms preprocess, 105.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 608x640 (no detections), 109.3ms
# Speed: 3.1ms preprocess, 109.3ms inference, 0.4ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 640x288 (no detections), 51.5ms
# Speed: 2.4ms preprocess, 51.5ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 288)
#
# 0: 640x640 1 door, 106.1ms
# Speed: 3.9ms preprocess, 106.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 576x640 1 door, 95.8ms
# Speed: 2.8ms preprocess, 95.8ms inference, 0.7ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 640x416 (no detections), 76.0ms
# Speed: 2.4ms preprocess, 76.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 544x640 1 door, 1 tyre, 140.1ms
# Speed: 3.1ms preprocess, 140.1ms inference, 0.8ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 480x640 5 persons, 5 motorcycles, 1 bus, 2 trucks, 79.6ms
# Speed: 3.3ms preprocess, 79.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 640x320 1 helmet, 57.1ms
# Speed: 2.5ms preprocess, 57.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 320)
#
# 0: 640x640 (no detections), 97.0ms
# Speed: 3.5ms preprocess, 97.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x608 1 door, 98.2ms
# Speed: 3.7ms preprocess, 98.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x288 (no detections), 58.3ms
# Speed: 2.0ms preprocess, 58.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 288)
#
# 0: 640x320 (no detections), 66.0ms
# Speed: 1.9ms preprocess, 66.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 320)
#
# 0: 640x544 (no detections), 97.4ms
# Speed: 3.1ms preprocess, 97.4ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 544)
#
# 0: 608x640 1 tyre, 110.2ms
# Speed: 3.5ms preprocess, 110.2ms inference, 0.7ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 640x288 (no detections), 59.7ms
# Speed: 1.6ms preprocess, 59.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 288)
#
# 0: 608x640 (no detections), 104.8ms
# Speed: 3.6ms preprocess, 104.8ms inference, 0.6ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 576x640 1 door, 135.4ms
# Speed: 6.5ms preprocess, 135.4ms inference, 0.9ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 door, 109.6ms
# Speed: 2.7ms preprocess, 109.6ms inference, 0.7ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 448x640 1 door, 1 helmet, 1 tyre, 72.6ms
# Speed: 2.7ms preprocess, 72.6ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 480x640 7 persons, 1 car, 5 motorcycles, 2 buss, 2 trucks, 79.9ms
# Speed: 3.9ms preprocess, 79.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 640x608 (no detections), 105.6ms
# Speed: 3.7ms preprocess, 105.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 (no detections), 100.5ms
# Speed: 3.6ms preprocess, 100.5ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x256 (no detections), 49.9ms
# Speed: 2.1ms preprocess, 49.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 256)
#
# 0: 640x512 (no detections), 85.4ms
# Speed: 4.1ms preprocess, 85.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x288 (no detections), 56.6ms
# Speed: 2.4ms preprocess, 56.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 288)
#
# 0: 608x640 (no detections), 103.2ms
# Speed: 3.1ms preprocess, 103.2ms inference, 0.4ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 640x352 (no detections), 63.5ms
# Speed: 2.3ms preprocess, 63.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x288 (no detections), 91.7ms
# Speed: 2.5ms preprocess, 91.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 288)
#
# 0: 640x640 1 door, 1 tyre, 100.7ms
# Speed: 3.3ms preprocess, 100.7ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 608x640 (no detections), 97.2ms
# Speed: 3.3ms preprocess, 97.2ms inference, 0.4ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 640x480 1 helmet, 79.8ms
# Speed: 2.8ms preprocess, 79.8ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 608x640 1 door, 103.0ms
# Speed: 3.2ms preprocess, 103.0ms inference, 0.7ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 544x640 1 door, 1 helmet, 102.0ms
# Speed: 3.0ms preprocess, 102.0ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 576x640 1 helmet, 1 tyre, 94.3ms
# Speed: 2.6ms preprocess, 94.3ms inference, 0.6ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 608x640 1 door, 1 helmet, 96.5ms
# Speed: 2.8ms preprocess, 96.5ms inference, 0.7ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 480x640 8 persons, 5 motorcycles, 1 bus, 3 trucks, 79.0ms
# Speed: 3.5ms preprocess, 79.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 640x608 1 door, 99.3ms
# Speed: 3.3ms preprocess, 99.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x640 (no detections), 111.7ms
# Speed: 3.1ms preprocess, 111.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x256 (no detections), 45.6ms
# Speed: 2.4ms preprocess, 45.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 256)
#
# 0: 640x448 (no detections), 107.7ms
# Speed: 3.1ms preprocess, 107.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x512 (no detections), 89.6ms
# Speed: 2.8ms preprocess, 89.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x288 (no detections), 51.8ms
# Speed: 1.9ms preprocess, 51.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 288)
#
# 0: 576x640 1 helmet, 95.8ms
# Speed: 3.3ms preprocess, 95.8ms inference, 0.7ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 608x640 (no detections), 107.1ms
# Speed: 3.0ms preprocess, 107.1ms inference, 0.4ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 640x320 (no detections), 66.1ms
# Speed: 2.2ms preprocess, 66.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 320)
#
# 0: 640x640 1 tyre, 112.9ms
# Speed: 3.4ms preprocess, 112.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x352 (no detections), 75.8ms
# Speed: 2.3ms preprocess, 75.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 608x640 1 door, 105.1ms
# Speed: 3.0ms preprocess, 105.1ms inference, 0.8ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 576x640 (no detections), 125.0ms
# Speed: 3.0ms preprocess, 125.0ms inference, 0.4ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 tyre, 133.7ms
# Speed: 3.4ms preprocess, 133.7ms inference, 0.8ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 480x640 6 persons, 5 motorcycles, 1 bus, 3 trucks, 81.5ms
# Speed: 3.6ms preprocess, 81.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 640x608 1 door, 116.3ms
# Speed: 2.8ms preprocess, 116.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 576x640 (no detections), 106.1ms
# Speed: 3.5ms preprocess, 106.1ms inference, 0.4ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 640x288 (no detections), 57.5ms
# Speed: 1.8ms preprocess, 57.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 288)
#
# 0: 640x256 (no detections), 54.5ms
# Speed: 2.6ms preprocess, 54.5ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 256)
#
# 0: 640x320 (no detections), 62.6ms
# Speed: 2.1ms preprocess, 62.6ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 320)
#
# 0: 640x512 (no detections), 98.1ms
# Speed: 3.2ms preprocess, 98.1ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 608x640 (no detections), 109.2ms
# Speed: 3.3ms preprocess, 109.2ms inference, 0.4ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 576x640 1 helmet, 90.9ms
# Speed: 3.5ms preprocess, 90.9ms inference, 0.7ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 640x224 (no detections), 41.2ms
# Speed: 1.8ms preprocess, 41.2ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 224)
#
# 0: 640x640 1 door, 141.4ms
# Speed: 3.7ms preprocess, 141.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x352 (no detections), 60.1ms
# Speed: 2.3ms preprocess, 60.1ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x480 1 tyre, 87.1ms
# Speed: 3.1ms preprocess, 87.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 608x640 1 door, 1 tyre, 183.6ms
# Speed: 3.6ms preprocess, 183.6ms inference, 0.6ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 448x640 1 helmet, 81.4ms
# Speed: 2.4ms preprocess, 81.4ms inference, 0.7ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 480x640 7 persons, 1 car, 6 motorcycles, 1 bus, 2 trucks, 88.4ms
# Speed: 3.0ms preprocess, 88.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 640x576 (no detections), 117.1ms
# Speed: 3.3ms preprocess, 117.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x352 (no detections), 78.3ms
# Speed: 2.5ms preprocess, 78.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 576x640 (no detections), 120.1ms
# Speed: 3.3ms preprocess, 120.1ms inference, 0.4ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 608x640 (no detections), 129.9ms
# Speed: 3.3ms preprocess, 129.9ms inference, 0.4ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 640x224 (no detections), 112.4ms
# Speed: 1.9ms preprocess, 112.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 224)
#
# 0: 640x288 (no detections), 66.6ms
# Speed: 2.0ms preprocess, 66.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 288)
#
# 0: 640x288 (no detections), 68.2ms
# Speed: 2.0ms preprocess, 68.2ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 288)
#
# 0: 576x640 (no detections), 104.3ms
# Speed: 3.5ms preprocess, 104.3ms inference, 0.4ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 640x480 (no detections), 88.8ms
# Speed: 2.8ms preprocess, 88.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x640 1 door, 109.5ms
# Speed: 2.8ms preprocess, 109.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 576x640 1 door, 1 tyre, 97.6ms
# Speed: 3.2ms preprocess, 97.6ms inference, 0.7ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 640x288 (no detections), 55.9ms
# Speed: 1.8ms preprocess, 55.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 288)
#
# 0: 576x640 1 door, 1 tyre, 92.0ms
# Speed: 2.9ms preprocess, 92.0ms inference, 0.7ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 640x320 (no detections), 59.2ms
# Speed: 1.7ms preprocess, 59.2ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 320)
#
# 0: 640x512 1 tyre, 127.0ms
# Speed: 3.8ms preprocess, 127.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 480x640 9 persons, 2 cars, 6 motorcycles, 1 bus, 3 trucks, 77.4ms
# Speed: 3.2ms preprocess, 77.4ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# 2025-01-11 12:03:41.461 Python[69328:5155189] +[IMKClient subclass]: chose IMKClient_Modern
# 2025-01-11 12:03:41.461 Python[69328:5155189] +[IMKInputSession subclass]: chose IMKInputSession_Modern
# 0: 640x608 (no detections), 114.0ms
# Speed: 3.1ms preprocess, 114.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x288 (no detections), 61.7ms
# Speed: 1.9ms preprocess, 61.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 288)
#
# 0: 640x640 (no detections), 98.1ms
# Speed: 3.1ms preprocess, 98.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x320 1 helmet, 57.7ms
# Speed: 2.4ms preprocess, 57.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 320)
#
# 0: 640x256 (no detections), 57.5ms
# Speed: 1.8ms preprocess, 57.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 256)
#
# 0: 640x512 (no detections), 93.1ms
# Speed: 2.6ms preprocess, 93.1ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x288 (no detections), 51.6ms
# Speed: 2.0ms preprocess, 51.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 288)
#
# 0: 640x320 (no detections), 55.9ms
# Speed: 2.0ms preprocess, 55.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 320)
#
# 0: 640x448 1 helmet, 75.6ms
# Speed: 2.7ms preprocess, 75.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x320 (no detections), 126.1ms
# Speed: 1.7ms preprocess, 126.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 320)
#
# 0: 608x640 1 door, 101.2ms
# Speed: 2.4ms preprocess, 101.2ms inference, 0.6ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 608x640 (no detections), 94.7ms
# Speed: 2.5ms preprocess, 94.7ms inference, 0.4ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 576x640 1 tyre, 94.4ms
# Speed: 2.8ms preprocess, 94.4ms inference, 0.7ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 tyre, 91.9ms
# Speed: 3.0ms preprocess, 91.9ms inference, 0.6ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 640x256 (no detections), 51.4ms
# Speed: 1.9ms preprocess, 51.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 256)
#
# 0: 448x640 1 door, 1 helmet, 73.3ms
# Speed: 2.3ms preprocess, 73.3ms inference, 0.6ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 640x384 (no detections), 79.4ms
# Speed: 19.1ms preprocess, 79.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x640 1 door, 112.9ms
# Speed: 3.8ms preprocess, 112.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 9 persons, 2 cars, 5 motorcycles, 1 bus, 2 trucks, 80.5ms
# Speed: 4.1ms preprocess, 80.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 640x608 1 tyre, 104.8ms
# Speed: 3.6ms preprocess, 104.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x256 (no detections), 54.3ms
# Speed: 1.6ms preprocess, 54.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 256)
#
# 0: 640x640 1 tyre, 99.5ms
# Speed: 3.6ms preprocess, 99.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x288 (no detections), 60.5ms
# Speed: 1.8ms preprocess, 60.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 288)
#
# 0: 640x320 1 helmet, 1 tyre, 58.8ms
# Speed: 1.7ms preprocess, 58.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 320)
#
# 0: 640x320 (no detections), 56.3ms
# Speed: 1.8ms preprocess, 56.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 320)
#
# 0: 640x480 (no detections), 72.4ms
# Speed: 2.5ms preprocess, 72.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 608x640 1 door, 101.5ms
# Speed: 3.4ms preprocess, 101.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 640x352 (no detections), 69.5ms
# Speed: 2.2ms preprocess, 69.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 608x640 (no detections), 104.6ms
# Speed: 3.1ms preprocess, 104.6ms inference, 0.4ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 640x256 (no detections), 76.7ms
# Speed: 3.0ms preprocess, 76.7ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 256)
#
# 0: 544x640 1 door, 1 tyre, 162.5ms
# Speed: 27.6ms preprocess, 162.5ms inference, 0.9ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 576x640 1 door, 1 tyre, 136.3ms
# Speed: 3.2ms preprocess, 136.3ms inference, 1.9ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 640x416 (no detections), 101.6ms
# Speed: 2.5ms preprocess, 101.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x416 (no detections), 76.7ms
# Speed: 3.4ms preprocess, 76.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x448 (no detections), 77.1ms
# Speed: 2.3ms preprocess, 77.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 480x640 9 persons, 2 cars, 6 motorcycles, 1 bus, 2 trucks, 78.1ms
# Speed: 3.5ms preprocess, 78.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 640x608 (no detections), 175.1ms
# Speed: 3.0ms preprocess, 175.1ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x640 1 tyre, 129.0ms
# Speed: 4.7ms preprocess, 129.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x256 (no detections), 63.9ms
# Speed: 2.9ms preprocess, 63.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 256)
#
# 0: 640x320 (no detections), 67.6ms
# Speed: 2.6ms preprocess, 67.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 320)
#
# 0: 640x512 (no detections), 93.8ms
# Speed: 2.4ms preprocess, 93.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x288 (no detections), 57.0ms
# Speed: 2.0ms preprocess, 57.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 288)
#
# 0: 640x352 1 tyre, 65.4ms
# Speed: 2.3ms preprocess, 65.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x320 (no detections), 103.1ms
# Speed: 2.5ms preprocess, 103.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 320)
#
# 0: 576x640 1 door, 1 tyre, 99.9ms
# Speed: 8.6ms preprocess, 99.9ms inference, 0.7ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 640x640 1 door, 103.4ms
# Speed: 3.0ms preprocess, 103.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x320 (no detections), 54.9ms
# Speed: 1.6ms preprocess, 54.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 320)
#
# 0: 640x640 (no detections), 99.5ms
# Speed: 3.7ms preprocess, 99.5ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x384 (no detections), 72.7ms
# Speed: 1.8ms preprocess, 72.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x320 (no detections), 89.2ms
# Speed: 2.8ms preprocess, 89.2ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 320)
#
# 0: 640x352 (no detections), 141.6ms
# Speed: 4.1ms preprocess, 141.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 79.6ms
# Speed: 3.2ms preprocess, 79.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x320 (no detections), 86.0ms
# Speed: 3.0ms preprocess, 86.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 320)
#
# 0: 640x320 (no detections), 93.4ms
# Speed: 2.8ms preprocess, 93.4ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 320)
#
# 0: 640x480 (no detections), 164.3ms
# Speed: 3.5ms preprocess, 164.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 480x640 9 persons, 2 cars, 4 motorcycles, 1 bus, 3 trucks, 130.0ms
# Speed: 4.1ms preprocess, 130.0ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 640x576 (no detections), 182.7ms
# Speed: 3.4ms preprocess, 182.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x608 (no detections), 156.8ms
# Speed: 4.5ms preprocess, 156.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x320 (no detections), 136.8ms
# Speed: 2.8ms preprocess, 136.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 320)
#
# 0: 640x288 1 door, 122.6ms
# Speed: 2.1ms preprocess, 122.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 288)
#
# 0: 640x288 (no detections), 69.4ms
# Speed: 2.1ms preprocess, 69.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 288)
#
# 0: 640x384 (no detections), 100.2ms
# Speed: 3.0ms preprocess, 100.2ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x480 (no detections), 105.9ms
# Speed: 2.7ms preprocess, 105.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 576x640 1 tyre, 87.4ms
# Speed: 3.8ms preprocess, 87.4ms inference, 0.8ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 640x320 (no detections), 89.3ms
# Speed: 2.0ms preprocess, 89.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 320)
#
# 0: 608x640 (no detections), 98.9ms
# Speed: 2.8ms preprocess, 98.9ms inference, 0.4ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 640x320 (no detections), 59.7ms
# Speed: 2.0ms preprocess, 59.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 320)
#
# 0: 640x352 (no detections), 62.6ms
# Speed: 1.9ms preprocess, 62.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 57.1ms
# Speed: 2.2ms preprocess, 57.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x640 1 door, 96.1ms
# Speed: 3.0ms preprocess, 96.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x320 (no detections), 51.3ms
# Speed: 1.7ms preprocess, 51.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 320)
#
# 0: 640x448 (no detections), 66.7ms
# Speed: 2.4ms preprocess, 66.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 480x640 1 helmet, 69.0ms
# Speed: 2.7ms preprocess, 69.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 9 persons, 2 cars, 4 motorcycles, 1 bus, 2 trucks, 88.5ms
# Speed: 3.0ms preprocess, 88.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 640x576 (no detections), 86.3ms
# ...
#
# 0: 640x416 (no detections), 55.0ms
# Speed: 1.4ms preprocess, 55.0ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x384 (no detections), 65.7ms
# Speed: 1.1ms preprocess, 65.7ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 480x640 6 persons, 5 cars, 2 motorcycles, 1 truck, 77.2ms
# Speed: 1.4ms preprocess, 77.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 640x640 1 tyre, 88.8ms
# Speed: 2.1ms preprocess, 88.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x288 (no detections), 53.1ms
# Speed: 0.9ms preprocess, 53.1ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 288)
#
# 0: 480x640 (no detections), 66.5ms
# Speed: 1.6ms preprocess, 66.5ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 608x640 2 tyres, 84.8ms
# Speed: 2.0ms preprocess, 84.8ms inference, 0.4ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 640x288 (no detections), 46.7ms
# Speed: 0.9ms preprocess, 46.7ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 288)
#
# 0: 640x288 (no detections), 41.4ms
# Speed: 1.3ms preprocess, 41.4ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 288)
#
# 0: 640x608 (no detections), 74.3ms
# Speed: 1.8ms preprocess, 74.3ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 384x640 1 tyre, 52.8ms
# Speed: 1.8ms preprocess, 52.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 288x640 (no detections), 38.7ms
# Speed: 1.5ms preprocess, 38.7ms inference, 0.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 640x384 (no detections), 51.3ms
# Speed: 1.2ms preprocess, 51.3ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 416x640 1 tyre, 57.0ms
# Speed: 1.9ms preprocess, 57.0ms inference, 0.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 480x640 8 persons, 5 cars, 3 motorcycles, 1 truck, 60.0ms
# Speed: 1.5ms preprocess, 60.0ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 576x640 2 tyres, 73.6ms
# Speed: 1.4ms preprocess, 73.6ms inference, 0.3ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 640x608 1 tyre, 85.5ms
# Speed: 1.8ms preprocess, 85.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x320 1 tyre, 47.7ms
# Speed: 1.3ms preprocess, 47.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 320)
#
# 0: 640x288 (no detections), 46.1ms
# Speed: 1.1ms preprocess, 46.1ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 288)
#
# 0: 640x288 (no detections), 50.4ms
# Speed: 1.2ms preprocess, 50.4ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 288)
#
# 0: 480x640 (no detections), 60.6ms
# Speed: 1.5ms preprocess, 60.6ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 352x640 (no detections), 54.4ms
# Speed: 1.4ms preprocess, 54.4ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 640x608 1 door, 73.8ms
# Speed: 1.9ms preprocess, 73.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x288 (no detections), 60.4ms
# Speed: 0.8ms preprocess, 60.4ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 288)
#
# 0: 640x224 (no detections), 27.1ms
# Speed: 1.1ms preprocess, 27.1ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 224)
#
# 0: 416x640 1 tyre, 53.4ms
# Speed: 1.3ms preprocess, 53.4ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 384x640 (no detections), 52.6ms
# Speed: 1.2ms preprocess, 52.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 (no detections), 58.5ms
# Speed: 1.4ms preprocess, 58.5ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x448 (no detections), 66.9ms
# Speed: 1.5ms preprocess, 66.9ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 480x640 8 persons, 6 cars, 3 motorcycles, 1 truck, 61.4ms
# Speed: 1.9ms preprocess, 61.4ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 576x640 1 tyre, 60.0ms
# Speed: 1.9ms preprocess, 60.0ms inference, 0.3ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 640x320 1 tyre, 39.5ms
# Speed: 1.0ms preprocess, 39.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 320)
#
# 0: 640x640 1 tyre, 73.3ms
# Speed: 1.9ms preprocess, 73.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x288 1 helmet, 37.5ms
# Speed: 1.2ms preprocess, 37.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 288)
#
# 0: 640x288 (no detections), 36.6ms
# Speed: 1.1ms preprocess, 36.6ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 288)
#
# 0: 416x640 (no detections), 52.7ms
# Speed: 2.0ms preprocess, 52.7ms inference, 0.2ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 640x256 (no detections), 31.7ms
# Speed: 1.1ms preprocess, 31.7ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 256)
#
# 0: 320x640 (no detections), 39.8ms
# Speed: 1.1ms preprocess, 39.8ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 416x640 1 helmet, 46.3ms
# Speed: 1.8ms preprocess, 46.3ms inference, 0.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 640x640 1 door, 72.3ms
# Speed: 2.2ms preprocess, 72.3ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x192 (no detections), 26.1ms
# Speed: 0.9ms preprocess, 26.1ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 192)
#
# 0: 640x608 1 door, 71.2ms
# Speed: 1.6ms preprocess, 71.2ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 480x640 7 persons, 5 cars, 4 motorcycles, 2 trucks, 63.6ms
# Speed: 1.8ms preprocess, 63.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 640x352 1 tyre, 85.2ms
# Speed: 1.4ms preprocess, 85.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x640 1 tyre, 98.4ms
# Speed: 2.5ms preprocess, 98.4ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 576x640 1 tyre, 87.0ms
# Speed: 1.4ms preprocess, 87.0ms inference, 0.4ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 640x288 (no detections), 65.0ms
# Speed: 2.4ms preprocess, 65.0ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 288)
#
# 0: 448x640 (no detections), 71.6ms
# Speed: 1.4ms preprocess, 71.6ms inference, 0.2ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 288x640 1 tyre, 53.8ms
# Speed: 0.9ms preprocess, 53.8ms inference, 0.4ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 640x288 (no detections), 63.7ms
# Speed: 1.0ms preprocess, 63.7ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 288)
#
# 0: 640x608 (no detections), 108.2ms
# Speed: 2.0ms preprocess, 108.2ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 384x640 (no detections), 49.7ms
# Speed: 1.0ms preprocess, 49.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 50.6ms
# Speed: 2.5ms preprocess, 50.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 480x640 (no detections), 59.2ms
# Speed: 1.0ms preprocess, 59.2ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 640x544 1 door, 78.5ms
# Speed: 1.3ms preprocess, 78.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 544)
#
# 0: 480x640 7 persons, 4 cars, 3 motorcycles, 2 trucks, 91.0ms
# Speed: 2.7ms preprocess, 91.0ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 640x384 1 tyre, 45.0ms
# Speed: 1.5ms preprocess, 45.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x640 2 tyres, 67.3ms
# Speed: 1.8ms preprocess, 67.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 448x640 (no detections), 46.6ms
# Speed: 1.3ms preprocess, 46.6ms inference, 0.2ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 288x640 2 helmets, 1 tyre, 34.0ms
# Speed: 1.7ms preprocess, 34.0ms inference, 0.3ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 640x288 (no detections), 32.2ms
# Speed: 0.9ms preprocess, 32.2ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 288)
#
# 0: 608x640 1 door, 2 tyres, 69.7ms
# Speed: 1.5ms preprocess, 69.7ms inference, 0.3ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 640x288 (no detections), 34.4ms
# Speed: 1.0ms preprocess, 34.4ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 288)
#
# 0: 640x576 (no detections), 58.8ms
# Speed: 1.2ms preprocess, 58.8ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x288 (no detections), 30.8ms
# Speed: 1.2ms preprocess, 30.8ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 288)
#
# 0: 416x640 (no detections), 44.2ms
# Speed: 1.1ms preprocess, 44.2ms inference, 0.2ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 42.4ms
# Speed: 1.2ms preprocess, 42.4ms inference, 0.2ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 640x384 (no detections), 51.4ms
# Speed: 1.6ms preprocess, 51.4ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 480x640 7 persons, 5 cars, 5 motorcycles, 2 trucks, 57.9ms
# Speed: 1.7ms preprocess, 57.9ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 608x640 2 tyres, 63.1ms
# Speed: 1.6ms preprocess, 63.1ms inference, 0.4ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 640x448 1 tyre, 47.2ms
# Speed: 1.7ms preprocess, 47.2ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 384x640 (no detections), 63.0ms
# Speed: 0.9ms preprocess, 63.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x608 1 tyre, 81.1ms
# Speed: 2.7ms preprocess, 81.1ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x320 (no detections), 41.2ms
# Speed: 1.1ms preprocess, 41.2ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 320)
#
# 0: 288x640 1 helmet, 32.9ms
# Speed: 1.2ms preprocess, 32.9ms inference, 0.3ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 640x288 (no detections), 34.4ms
# Speed: 0.9ms preprocess, 34.4ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 288)
#
# 0: 640x288 (no detections), 34.4ms
# Speed: 1.1ms preprocess, 34.4ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 288)
#
# 0: 416x640 (no detections), 49.8ms
# Speed: 1.2ms preprocess, 49.8ms inference, 0.2ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 640x640 (no detections), 76.6ms
# Speed: 1.4ms preprocess, 76.6ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x384 (no detections), 50.7ms
# Speed: 0.9ms preprocess, 50.7ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 448x640 1 helmet, 1 tyre, 49.6ms
# Speed: 1.3ms preprocess, 49.6ms inference, 0.3ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 608x640 (no detections), 75.2ms
# Speed: 1.4ms preprocess, 75.2ms inference, 0.2ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 480x640 6 persons, 5 cars, 4 motorcycles, 2 trucks, 89.8ms
# Speed: 1.7ms preprocess, 89.8ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 640x448 1 tyre, 54.1ms
# Speed: 1.8ms preprocess, 54.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x640 1 door, 1 tyre, 81.2ms
# Speed: 1.7ms preprocess, 81.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 288x640 1 helmet, 1 tyre, 31.8ms
# Speed: 1.2ms preprocess, 31.8ms inference, 0.3ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 640x576 1 tyre, 75.0ms
# Speed: 1.6ms preprocess, 75.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x288 (no detections), 45.7ms
# Speed: 1.2ms preprocess, 45.7ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 288)
#
# 0: 384x640 (no detections), 54.3ms
# Speed: 1.6ms preprocess, 54.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x320 (no detections), 36.1ms
# Speed: 1.5ms preprocess, 36.1ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 320)
#
# 0: 416x640 (no detections), 45.7ms
# Speed: 1.3ms preprocess, 45.7ms inference, 0.2ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 640x256 (no detections), 33.6ms
# Speed: 0.7ms preprocess, 33.6ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 256)
#
# 0: 640x384 (no detections), 44.2ms
# Speed: 1.0ms preprocess, 44.2ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x608 (no detections), 68.0ms
# Speed: 1.6ms preprocess, 68.0ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 448x640 1 tyre, 45.4ms
# Speed: 1.4ms preprocess, 45.4ms inference, 0.3ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 576x640 (no detections), 68.3ms
# Speed: 1.7ms preprocess, 68.3ms inference, 0.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 480x640 7 persons, 4 cars, 3 motorcycles, 2 trucks, 54.4ms
# Speed: 1.8ms preprocess, 54.4ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 640x480 1 tyre, 49.9ms
# Speed: 1.5ms preprocess, 49.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x640 (no detections), 65.3ms
# Speed: 1.5ms preprocess, 65.3ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 608x640 1 tyre, 66.2ms
# Speed: 1.7ms preprocess, 66.2ms inference, 0.3ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 640x288 1 helmet, 31.6ms
# Speed: 1.6ms preprocess, 31.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 288)
#
# 0: 384x640 (no detections), 37.6ms
# Speed: 1.1ms preprocess, 37.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 288x640 1 tyre, 32.5ms
# Speed: 1.1ms preprocess, 32.5ms inference, 0.3ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 640x288 (no detections), 32.6ms
# Speed: 1.0ms preprocess, 32.6ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 288)
#
# 0: 640x288 (no detections), 34.6ms
# Speed: 1.0ms preprocess, 34.6ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 288)
#
# 0: 448x640 (no detections), 47.2ms
# Speed: 1.2ms preprocess, 47.2ms inference, 0.2ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 640x256 (no detections), 31.6ms
# Speed: 1.0ms preprocess, 31.6ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 256)
#
# 0: 576x640 (no detections), 58.0ms
# Speed: 1.4ms preprocess, 58.0ms inference, 0.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 640x576 (no detections), 59.9ms
# Speed: 1.5ms preprocess, 59.9ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x416 (no detections), 45.2ms
# Speed: 1.4ms preprocess, 45.2ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 480x640 6 persons, 4 cars, 4 motorcycles, 2 trucks, 64.6ms
# Speed: 1.4ms preprocess, 64.6ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 640x288 (no detections), 38.8ms
# Speed: 1.0ms preprocess, 38.8ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 288)
#
# 0: 288x640 (no detections), 38.3ms
# Speed: 1.6ms preprocess, 38.3ms inference, 0.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 640x288 (no detections), 34.2ms
# Speed: 1.2ms preprocess, 34.2ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 288)
#
# 0: 640x544 1 tyre, 69.7ms
# Speed: 1.9ms preprocess, 69.7ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 544)
#
# 0: 416x640 (no detections), 47.7ms
# Speed: 1.4ms preprocess, 47.7ms inference, 1.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 640x512 1 door, 1 tyre, 56.5ms
# Speed: 1.5ms preprocess, 56.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x640 2 tyres, 67.0ms
# Speed: 1.8ms preprocess, 67.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x256 (no detections), 59.1ms
# Speed: 0.9ms preprocess, 59.1ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 256)
#
# 0: 480x640 (no detections), 92.8ms
# Speed: 1.4ms preprocess, 92.8ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 640x384 (no detections), 48.9ms
